# %% [markdown]
# # 4.6 GPU计算

# %%
# !nvidia-smi # 对Linux/macOS用户有效
# Out:
# 'nvidia-smi' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
import torch
from torch import nn

print(torch.__version__)
# Out:
# 1.13.1+cpu

# %% [markdown]
# ## 4.6.1 计算设备

# %%
torch.cuda.is_available() # cuda是否可用
# Out:
# False

# %%
torch.cuda.device_count() # gpu数量
# Out:
# 0

# %%
torch.cuda.current_device() # 当前设备索引, 从0开始
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13868\174099066.py in <module>
# ----> 1 torch.cuda.current_device() # 当前设备索引, 从0开始
#
# d:\Python\Miniforge\envs\d2l_pytorch\lib\site-packages\torch\cuda\__init__.py in current_device()
#     550 def current_device() -> int:
#     551     r"""Returns the index of a currently selected device."""
# --> 552     _lazy_init()
#     553     return torch._C._cuda_getDevice()
#     554
#
# d:\Python\Miniforge\envs\d2l_pytorch\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     219                 "multiprocessing, you must use the 'spawn' start method")
#     220         if not hasattr(torch._C, '_cuda_getDeviceCount'):
# --> 221             raise AssertionError("Torch not compiled with CUDA enabled")
#     222         if _cudart is None:
#     223             raise AssertionError(
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
torch.cuda.get_device_name(0) # 返回gpu名字
# Out:
# 'GeForce GTX 1050'

# %% [markdown]
# ## 4.6.2 `Tensor`的GPU计算

# %%
x = torch.tensor([1, 2, 3])
x
# Out:
# tensor([1, 2, 3])

# %%
x = x.cuda(0)
x
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %%
x.device
# Out:
# device(type='cuda', index=0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

x = torch.tensor([1, 2, 3], device=device)
# or
x = torch.tensor([1, 2, 3]).to(device)
x
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %%
y = x**2
y
# Out:
# tensor([1, 4, 9], device='cuda:0')

# %%
# z = y + x.cpu()

# %% [markdown]
# ## 4.6.3 模型的GPU计算

# %%
net = nn.Linear(3, 1)
list(net.parameters())[0].device
# Out:
# device(type='cpu')

# %%
net.cuda()
list(net.parameters())[0].device
# Out:
# device(type='cuda', index=0)

# %%
x = torch.rand(2,3).cuda()
net(x)
# Out:
# tensor([[-0.5574],
#         [-0.3792]], device='cuda:0', grad_fn=<ThAddmmBackward>)
